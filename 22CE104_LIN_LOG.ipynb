# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('test_data.csv')
df.head(10)
# Out:
#     index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0  375734  0.0  0.833333   11/1/22                              339.88
# 1  375735  0.0  0.833333   11/2/22                              334.63
# 2  375736  0.0  0.833333   11/3/22                              337.83
# 3  375737  0.0  0.833333   11/4/22                              345.81
# 4  375738  0.0  0.833333   11/5/22                              357.39
# 5  375739  0.0  0.833333   11/6/22                              370.15
# 6  375740  0.0  0.833333   11/7/22                              375.72
# 7  375741  0.0  0.833333   11/8/22                              372.04
# 8  375742  0.0  0.833333   11/9/22                              357.62
# 9  375743  0.0  0.833333  11/10/22                              346.90
#
#    nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                     30.88                     30.92
# 1                     30.88                     30.92
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      375734  0.0  0.833333   11/1/22                              339.88
# 1      375735  0.0  0.833333   11/2/22                              334.63
# 2      375736  0.0  0.833333   11/3/22                              337.83
# 3      375737  0.0  0.833333   11/4/22                              345.81
# 4      375738  0.0  0.833333   11/5/22                              357.39
# ...       ...  ...       ...       ...                                 ...
# 31349  407083  1.0  0.866667  12/27/22                               62.72
# 31350  407084  1.0  0.866667  12/28/22                               73.41
# 31351  407085  1.0  0.866667  12/29/22                               70.00
# 31352  407086  1.0  0.866667  12/30/22                               79.81
# 31353  407087  1.0  0.866667  12/31/22                               86.17
#
# ...

# %%
X = df['nmme-tmp2m-56w__cancm4']
y = df['nmme-tmp2m-56w__cfsv2']

# %%
X=X.values.reshape(-1,1)
y=y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X)
plt.scatter(X, y,color = 'blue')
plt.plot(X, y_pred , color = 'green')
plt.scatter(y_pred , y, color ='red')
plt.legend
plt.show()

# %%
from sklearn.metrics import r2_score , accuracy_score

print('Accuracy:',accuracy_score(y_pred,y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 3
#       1 from sklearn.metrics import r2_score , accuracy_score
# ----> 3 print('Accuracy:',accuracy_score(y_pred,y))
#
# File d:\MLwork\.venv\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
# ...

# %% [markdown]
# **LOGISTIC**

# %%
import pandas as pd
import numpy as np 
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('test_data.csv')
data.head(10)
# Out:
#     index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0  375734  0.0  0.833333   11/1/22                              339.88
# 1  375735  0.0  0.833333   11/2/22                              334.63
# 2  375736  0.0  0.833333   11/3/22                              337.83
# 3  375737  0.0  0.833333   11/4/22                              345.81
# 4  375738  0.0  0.833333   11/5/22                              357.39
# 5  375739  0.0  0.833333   11/6/22                              370.15
# 6  375740  0.0  0.833333   11/7/22                              375.72
# 7  375741  0.0  0.833333   11/8/22                              372.04
# 8  375742  0.0  0.833333   11/9/22                              357.62
# 9  375743  0.0  0.833333  11/10/22                              346.90
#
#    nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                     30.88                     30.92
# 1                     30.88                     30.92
# ...

# %%
numeric_columns = ['nmme-prate-56w__ccsm3', 'nmme-prate-56w__nasa', 'wind-vwnd-925-2010-20']
X = data[numeric_columns]
Y = data['contest-wind-uwnd-925-14d__wind-uwnd-925'].values
#find the mean value of the Y column
mean = np.mean(Y)
Y = np.where(Y > mean, 'Y','N')
print(Y)
# Out:
# ['N' 'N' 'N' ... 'Y' 'Y' 'Y']

# %%
x_train,x_test,y_train,y_test=train_test_split(X, Y,test_size=0.2,random_state=42)
lr=LogisticRegression(max_iter=4000)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# ['Y' 'Y' 'N' ... 'N' 'Y' 'Y']

# %%
import seaborn as sns
from sklearn import metrics
cm = metrics.confusion_matrix(y_test, y_pred)
cm

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=lr.classes_, yticklabels=lr.classes_)
plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 61.55
