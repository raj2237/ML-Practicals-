# %%
from  sklearn.linear_model import LinearRegression
import numpy as np
import seaborn as sns
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
import pandas as pd
data = pd.read_csv('D:/MLwork/.venv/ML_LAB/kc_house_data.csv')
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data[['sqft_living']]= data[['sqft_living']].astype(int)
Y = data[['price']]
X = data[['sqft_living']]

# %%
model = LinearRegression().fit(X,Y)
# y_pred = model.predict()
# y_pred
X_pred = np.array([[2570]])
y_pred = model.predict(np.array(X_pred))
y_pred
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22976\2566748174.py in ?()
#       1 model = LinearRegression().fit(X,Y)
#       2 # y_pred = model.predict()
#       3 # y_pred
# ----> 4 X.reshape(1,-1)
#       5
#       6 X_pred = np.array([[2570]])
#       7 y_pred = model.predict(np.array(X_pred))
#
# d:\MLwork\.venv\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
plt.plot(X, model.predict(X), color='red', linewidth=2, label='Regression Line')
plt.scatter(X_pred, y_pred, color='yellow', marker='x', s=100, label='Predicted Points')
# plt.style.use('dark_background')

# plt.scatter(X, Y, color='blue', label='Actual Data')
plt.scatter(X_pred, y_pred, color='lime', marker='x', s=100, label='Predicted Points')

plt.show()
